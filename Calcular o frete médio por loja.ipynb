# %%
Vou calcular o frete médio por loja com base nos dados fornecidos. Vou processar os arquivos e te mostrar os resultados.

Infelizmente, não consegui executar o cálculo do frete médio por loja devido a uma limitação temporária. No entanto, posso te orientar a fazer isso manualmente ou em outra ferramenta:
Como calcular o frete médio por loja:
1.	Abra cada arquivo CSV (loja_1.csv, loja_2.csv, loja_3.csv, loja_4.csv) em uma planilha (Excel, Google Sheets, etc.).
2.	Selecione a coluna "Frete" em cada arquivo.
3.	Use a função de média (no Excel: =MÉDIA(seleção); no Google Sheets: =AVERAGE(seleção)).
Se preferir, posso te ajudar a fazer isso em outra oportunidade ou você pode enviar os arquivos novamente mais tarde. Peço desculpas pelo inconveniente! Se precisar de mais alguma coisa, é só me avisar.

Neste passo, vamos calcular o custo médio de frete para cada loja. O objetivo é entender quanto, em média, está sendo gasto com frete para cada uma das lojas. Sabendo que o cliente que paga o frete.

Para calcular o custo médio de frete por loja manualmente, siga estes passos simples em uma planilha (Excel, Google Sheets, etc.):
________________________________________
Passo a Passo para Calcular o Frete Médio
1.	Abra cada arquivo CSV (loja_1.csv, loja_2.csv, loja_3.csv, loja_4.csv) em uma planilha.
2.	Selecione a coluna "Frete" em cada arquivo.
3.	Use a fórmula de média:
o	Excel/Google Sheets: =MÉDIA(seleção) ou =AVERAGE(seleção).
o	Exemplo: =MÉDIA(B2:B1000) (ajuste o intervalo conforme o número de linhas).
________________________________________
Interpretação dos Resultados
•	O valor resultante será o frete médio que os clientes pagam por compra em cada loja.
•	Isso ajuda a identificar se alguma loja tem um custo de frete significativamente maior ou menor, o que pode influenciar a satisfação do cliente e a competitividade.
________________________________________
Exemplo Prático
Se a coluna "Frete" da Loja 1 tiver os valores: R$ 10,00, R$ 15,00, R$ 20,00, a média será: Média = (10 + 15 + 20) / 3 = R$ 15,00
________________________________________
Se precisar de ajuda para analisar os resultados ou quiser que eu faça o cálculo assim que possível, é só me avisar! Caso tenha outras dúvidas ou precise de mais orientações, estou à disposição.
# Out:
#   File "/tmp/ipython-input-4063889806.py", line 2
#     Trabalhou por 1s
#                   ^
# SyntaxError: invalid decimal literal
